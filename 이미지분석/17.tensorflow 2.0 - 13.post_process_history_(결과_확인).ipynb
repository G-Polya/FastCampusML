# %% [markdown]
# # TensorFlow 2.0

# %%
import os
from glob import glob
from datetime import datetime

import numpy as np

import tensorflow as tf
from tensorflow.keras import layers

from tensorflow.keras import datasets 

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Hyperparameter Tunning

# %%
num_epochs = 50
batch_size = 32

learning_rate = 0.001

dropout_rate = 0.5

input_shape = (32, 32, 3)
num_classes = 10

# %% [markdown]
# ## Build Model

# %%
inputs = layers.Input(input_shape)

net = layers.Conv2D(32, (3, 3), padding='SAME')(inputs)
net = layers.Activation('relu')(net)
net = layers.Conv2D(32, (3, 3), padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.MaxPooling2D(pool_size=(2, 2))(net)
net = layers.Dropout(dropout_rate)(net)

net = layers.Conv2D(64, (3, 3), padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.Conv2D(64, (3, 3), padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.MaxPooling2D(pool_size=(2, 2))(net)
net = layers.Dropout(dropout_rate)(net)

net = layers.Flatten()(net)
net = layers.Dense(512)(net)
net = layers.Activation('relu')(net)
net = layers.Dropout(dropout_rate)(net)
net = layers.Dense(num_classes)(net)
net = layers.Activation('softmax')(net)

model = tf.keras.Model(inputs=inputs, outputs=net, name='Basic_CNN')

# %%
# Model is the full model w/o custom layers
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),  # Optimization
              loss='sparse_categorical_crossentropy',  # Loss Function 
              metrics=['accuracy'])  # Metrics / Accuracy

# %% [markdown]
# # Data Preprocess

# %%
train_paths = glob('dataset/cifar/train/*.png')[:1000]
test_paths = glob('dataset/cifar/test/*.png')[:1000]

# %%
def get_class_name(path):
    return path.split('_')[-1].replace('.png', '')

# %%
train_labels = [get_class_name(path) for path in train_paths]
class_names = np.unique(train_labels)

# %%
def get_label(path):
    fname = tf.strings.split(path, '_')[-1]
    lbl_name = tf.strings.regex_replace(fname, '.png', '')
    onehot = tf.cast(lbl_name == class_names, tf.uint8)
    return tf.argmax(onehot)  # 이번에는 onehot이 아닌 label 번호로

# %%
def load_image_label(path):
    gfile = tf.io.read_file(path)
    image = tf.io.decode_image(gfile)
    image = tf.cast(image, tf.float32) / 255.  # rescale
    
    label = get_label(path)
    return image, label

# %%
def image_preprocess(image, label):
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_flip_left_right(image)
    return image, label

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(train_paths)
train_dataset = train_dataset.map(load_image_label, num_parallel_calls=AUTOTUNE)
train_dataset = train_dataset.map(image_preprocess, num_parallel_calls=AUTOTUNE)
train_dataset = train_dataset.batch(batch_size)
train_dataset = train_dataset.shuffle(buffer_size=len(train_paths))
train_dataset = train_dataset.repeat()

# %%
test_dataset = tf.data.Dataset.from_tensor_slices(test_paths)
test_dataset = test_dataset.map(load_image_label, num_parallel_calls=AUTOTUNE)
test_dataset = test_dataset.batch(batch_size)
test_dataset = test_dataset.repeat()

# %% [markdown]
# ## Training

# %% [markdown]
# http://localhost:6006

# %%
steps_per_epoch = len(train_paths) // batch_size
validation_steps = len(test_paths) // batch_size

history = model.fit_generator(
    train_dataset,
    steps_per_epoch=steps_per_epoch,
    validation_data=test_dataset,
    validation_steps=validation_steps,
    epochs=num_epochs
)
# Out:
# WARNING:tensorflow:From <ipython-input-14-ace97a0ab232>:9: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 31/31 [==============================] - 1s 20ms/step - loss: 2.3179 - accuracy: 0.1064 - val_loss: 2.3017 - val_accuracy: 0.0897
# Epoch 2/50
# 31/31 [==============================] - 0s 12ms/step - loss: 2.2821 - accuracy: 0.1147 - val_loss: 2.2429 - val_accuracy: 0.1653
# Epoch 3/50
# 31/31 [==============================] - 0s 13ms/step - loss: 2.2192 - accuracy: 0.1885 - val_loss: 2.1320 - val_accuracy: 0.2056
# Epoch 4/50
# 31/31 [==============================] - 0s 13ms/step - loss: 2.1589 - accuracy: 0.1981 - val_loss: 2.0941 - val_accuracy: 0.2329
# Epoch 5/50
# 31/31 [==============================] - 0s 13ms/step - loss: 2.0898 - accuracy: 0.2169 - val_loss: 2.0186 - val_accuracy: 0.2359
# Epoch 6/50
# 31/31 [==============================] - 0s 12ms/step - loss: 2.0913 - accuracy: 0.2117 - val_loss: 2.0575 - val_accuracy: 0.2560
# Epoch 7/50
# 31/31 [==============================] - 0s 13ms/step - loss: 2.0389 - accuracy: 0.2362 - val_loss: 2.0226 - val_accuracy: 0.2399
# Epoch 8/50
# 31/31 [==============================] - 0s 13ms/step - loss: 1.9825 - accuracy: 0.2933 - val_loss: 1.9292 - val_accuracy: 0.2833
# Epoch 9/50
# 31/31 [==============================] - 0s 13ms/step - loss: 1.9241 - accuracy: 0.2786 - val_loss: 1.9587 - val_accuracy: 0.2762
# Epoch 10/50
# 31/31 [==============================] - 0s 13ms/step - loss: 1.8814 - accuracy: 0.2913 - val_loss: 1.8996 - val_accuracy: 0.2964
# Epoch 11/50
# 31/31 [==============================] - 0s 13ms/step - loss: 1.8846 - accuracy: 0.3017 - val_loss: 1.8798 - val_accuracy: 0.3478
# Epoch 12/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.8005 - accuracy: 0.3233 - val_loss: 1.8399 - val_accuracy: 0.3357
# Epoch 13/50
# 31/31 [==============================] - 0s 14ms/step - loss: 1.8179 - accuracy: 0.3295 - val_loss: 1.8271 - val_accuracy: 0.3337
# Epoch 14/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.7878 - accuracy: 0.3502 - val_loss: 1.8519 - val_accuracy: 0.3155
# Epoch 15/50
# 31/31 [==============================] - 0s 13ms/step - loss: 1.7563 - accuracy: 0.3574 - val_loss: 1.7805 - val_accuracy: 0.3367
# Epoch 16/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.7320 - accuracy: 0.3508 - val_loss: 1.9298 - val_accuracy: 0.3357
# Epoch 17/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.6521 - accuracy: 0.3909 - val_loss: 1.8738 - val_accuracy: 0.3054
# Epoch 18/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.7303 - accuracy: 0.3667 - val_loss: 1.7712 - val_accuracy: 0.3770
# Epoch 19/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.6116 - accuracy: 0.4103 - val_loss: 1.7171 - val_accuracy: 0.3861
# Epoch 20/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.6080 - accuracy: 0.4122 - val_loss: 1.7141 - val_accuracy: 0.3800
# Epoch 21/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.5936 - accuracy: 0.4411 - val_loss: 1.7091 - val_accuracy: 0.4153
# Epoch 22/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.6265 - accuracy: 0.4131 - val_loss: 1.7297 - val_accuracy: 0.3942
# Epoch 23/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.5641 - accuracy: 0.4256 - val_loss: 1.7437 - val_accuracy: 0.3589
# Epoch 24/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.5598 - accuracy: 0.4325 - val_loss: 1.6611 - val_accuracy: 0.3931
# Epoch 25/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.5245 - accuracy: 0.4401 - val_loss: 1.7001 - val_accuracy: 0.3871
# Epoch 26/50
# 31/31 [==============================] - 0s 13ms/step - loss: 1.4972 - accuracy: 0.4618 - val_loss: 1.7104 - val_accuracy: 0.4062
# Epoch 27/50
# 31/31 [==============================] - 0s 13ms/step - loss: 1.4404 - accuracy: 0.4783 - val_loss: 1.6758 - val_accuracy: 0.3972
# Epoch 28/50
# 31/31 [==============================] - 0s 13ms/step - loss: 1.5094 - accuracy: 0.4504 - val_loss: 1.7699 - val_accuracy: 0.3750
# Epoch 29/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.4365 - accuracy: 0.4804 - val_loss: 1.6823 - val_accuracy: 0.3911
# Epoch 30/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.3754 - accuracy: 0.5217 - val_loss: 1.7105 - val_accuracy: 0.4113
# Epoch 31/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.3728 - accuracy: 0.4814 - val_loss: 1.7508 - val_accuracy: 0.4204
# Epoch 32/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.3457 - accuracy: 0.5041 - val_loss: 1.7998 - val_accuracy: 0.4012
# Epoch 33/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.3396 - accuracy: 0.5093 - val_loss: 1.6972 - val_accuracy: 0.4002
# Epoch 34/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.3133 - accuracy: 0.5258 - val_loss: 1.6511 - val_accuracy: 0.4224
# Epoch 35/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.2996 - accuracy: 0.5269 - val_loss: 1.7089 - val_accuracy: 0.4274
# Epoch 36/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.2694 - accuracy: 0.5486 - val_loss: 1.6642 - val_accuracy: 0.4294
# Epoch 37/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.1954 - accuracy: 0.5620 - val_loss: 1.6940 - val_accuracy: 0.4335
# Epoch 38/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.1767 - accuracy: 0.5930 - val_loss: 1.7552 - val_accuracy: 0.4395
# Epoch 39/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.2043 - accuracy: 0.5455 - val_loss: 1.7926 - val_accuracy: 0.4345
# Epoch 40/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.1782 - accuracy: 0.5919 - val_loss: 1.7119 - val_accuracy: 0.4052
# Epoch 41/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.1959 - accuracy: 0.5620 - val_loss: 1.6545 - val_accuracy: 0.4315
# Epoch 42/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.1382 - accuracy: 0.5968 - val_loss: 1.7230 - val_accuracy: 0.4365
# Epoch 43/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.1466 - accuracy: 0.6012 - val_loss: 1.7864 - val_accuracy: 0.4355
# Epoch 44/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.0528 - accuracy: 0.6064 - val_loss: 1.7556 - val_accuracy: 0.4365
# Epoch 45/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.1103 - accuracy: 0.5930 - val_loss: 1.6800 - val_accuracy: 0.4476
# Epoch 46/50
# 31/31 [==============================] - 0s 12ms/step - loss: 0.9836 - accuracy: 0.6529 - val_loss: 1.7929 - val_accuracy: 0.4254
# Epoch 47/50
# 31/31 [==============================] - 0s 12ms/step - loss: 1.1019 - accuracy: 0.5919 - val_loss: 1.7654 - val_accuracy: 0.4506
# Epoch 48/50
# 31/31 [==============================] - 0s 12ms/step - loss: 0.9511 - accuracy: 0.6725 - val_loss: 1.7625 - val_accuracy: 0.4567
# Epoch 49/50
# 31/31 [==============================] - 0s 12ms/step - loss: 0.9286 - accuracy: 0.6578 - val_loss: 1.8063 - val_accuracy: 0.4425
# Epoch 50/50
# 31/31 [==============================] - 0s 12ms/step - loss: 0.9240 - accuracy: 0.6560 - val_loss: 1.9132 - val_accuracy: 0.4446

# %% [markdown]
# # History 들여다 보기

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 50, 'steps': 31}

# %%
new_model = history.model
new_model

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title("Model Accuaracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["train","validation"])
plt.show()

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model loss")
plt.ylabel("loss")
plt.xlabel("Epoch")
plt.legend(["train", "validation"])
plt.show()
